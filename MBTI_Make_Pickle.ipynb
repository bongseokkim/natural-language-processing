# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Load Data

# %%
import pandas as pd 
import numpy as np
from tqdm import tqdm

# %%
% cd '/content/gdrive/MyDrive/MBTI'
# Out:
# /content/gdrive/MyDrive/MBTI

# %%
import os
from glob import glob 

data_name_list = glob("*.csv")
data_name_list 
data_dict = {}

for name in data_name_list :
  path = os.path.join(name)
  data = pd.read_csv(path,encoding='cp949', index_col=0)
  data_dict[str(name[0:4])] = data 

print(f'Succesfully loaded {len(data_dict)} data')
# Out:
# Succesfully loaded 16 data

# %%
data_dict['ESTJ'].head()
# Out:
#    num                   title                          content
# 1    4                 ESTJ갤러리                               -
# 2    7           아따잉 첫빠여라~~ ㅋㅋ           반갑소잉~~<U+00A0>
# 3    9             여긴 왜 사람이 없냐                         존나 조용하네
# 4   10    estj는 인싸들이어서 글쓸시간도없음                     근데 나도 estj임
# 5   11  MBTI 갤러리에서 떡 돌리러 왔습니다.                          반갑습니다.

# %%
# labeling 
for label in data_dict.keys():
  data_dict[label]['label'] = label

# %%
#checking 
data_dict['ESTJ'].head()
# Out:
#    num                   title                          content label
# 1    4                 ESTJ갤러리                               -   ESTJ
# 2    7           아따잉 첫빠여라~~ ㅋㅋ           반갑소잉~~<U+00A0>          ESTJ
# 3    9             여긴 왜 사람이 없냐                         존나 조용하네   ESTJ
# 4   10    estj는 인싸들이어서 글쓸시간도없음                     근데 나도 estj임   ESTJ
# 5   11  MBTI 갤러리에서 떡 돌리러 왔습니다.                          반갑습니다.   ESTJ

# %%
# contcat intto one data_set 
result = pd.DataFrame()
for label in data_dict.keys():
  result = pd.concat([result, data_dict[label]])

result = result.drop('num', axis=1)
result = result.reset_index().drop(['index'],axis=1)

# %%
result.head()
# Out:
#                        title                                 content label
# 0                   사랑해요 엔프제           천사가 있다면 당신일 것<U+00A0>          ENFJ
# 1                         ㅎㅇ                              너희들 다 내 거임  ENFJ
# 2                 엔프제 갤러리 특)                  엔프제는 없고엔프제를 보려는 관객만 있다  ENFJ
# 3  갤주는 갤이름 대문자로 바꿔라. ㅈㄴ 불편하네                                     NaN  ENFJ
# 4                       ㅎㅇㅎㅇ                               엔갤 흥하길 바람  ENFJ

# %%
result['title'] = result['title'].str.strip() #공백제거
result['content'] = result['content'].str.strip() # 공백제거

result['title'].replace('',np.nan, inplace=True) # 제목없는 경우 nan 대체
result['content'].replace('', np.nan, inplace=True)

result.dropna()

result.tail()
# Out:
#                                 title  ... label
# 28237                       응애 나 아기인팁  ...  INTP
# 28238                       인팁은 악필이냐?  ...  INTP
# 28239                         이제 깨달았다  ...  INTP
# 28240                         와시발 턱걸이  ...  INTP
# 28241  저거 아이큐에서 10정도 빼야 실제 아이큐랑 근사할듯.  ...  INTP
#
# [5 rows x 3 columns]

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.8MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 8.0MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/98/88/f817ef1af6f794e8f11313dcd1549de833f4599abcec82746ab5ed086686/JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 32.3MB/s
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: beautifulsoup4, colorama, JPype1, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
from konlpy.tag import Hannanum

# %%
extractor = Hannanum()
nouns = []

for i, row, in tqdm(result.iterrows()):
  title, content,label = row

  if title and type(title) is str:
    nouns.extend(extractor.nouns(title))

  if content and type(content) is str:
     nouns.extend(extractor.nouns(content))
# Out:
# 28242it [06:09, 76.49it/s]

# %% [markdown]
# ## Count Word

# %%
nouns
# Out:
# ['사랑',
#  '엔프제',
#  '천사',
#  '당신',
#  '것<U+00A0',
#  'ㅎㅇ',
#  '너희들',
#  '내',
#  '거',
#  '엔프제',
#  '갤러리',
#  '특',
#  '엔프제',
#  '없고엔프제',
#  '관객',
#  '갤주',
#  '갤이름',
#  '대문자',
#  'ㅈㄴ',
#  '불편',
#  'ㅎㅇㅎㅇ',
#  '엔갤',
#  '흥하길',
#  '바람',
#  '엔프제',
#  '노무',
#  '니네',
#  '성격',
#  '나줘ㅡㅡ',
#  '유사',
#  '엔프제',
#  '입갤',
#  '인프제',
#  '엔프제',
#  '쳐달란',
#  '말',
#  'ㅡㅡ',
#  '현실',
#  '어디',
#  '잘보',
#  '데',
#  '극소수',
#  '유형',
#  '동족',
#  '찾는거보다',
#  '더찾기힘듬',
#  '엔프제',
#  '멘탈',
#  '내',
#  '주위',
#  '엔프제',
#  '엔프제',
#  '갤도있',
#  '저',
#  '처음검사',
#  '5년',
#  '엔프제',
#  '엔프제예요',
#  '잘',
#  '안나오',
#  '지',
#  '전',
#  '소문자',
#  '모습',
#  '뭔가',
#  '옆',
#  '순환표시',
#  '똥글똘글해서',
#  '귀여워요가끔',
#  '놀러올게요',
#  '엔프제에',
#  '호감',
#  '어케해야할까요',
#  '엔프제',
#  '마음',
#  '뺏고싶은데지금',
#  '어느정도',
#  '친한정도까진',
#  '데',
#  '데',
#  '어케해야',
#  '저',
#  '엔프제',
#  '성격유형',
#  '엔프제',
#  '호감',
#  '법',
#  '에너지',
#  '발산',
#  '때',
#  '에너지',
#  '받아주면됨근데',
#  '그',
#  '입장',
#  '에너지',
#  '생각이유',
#  '엔프제',
#  '눈치',
#  '존',
#  '빨라서상대방',
#  '귀찮아하는거',
#  '대화',
#  '니랑',
#  'ㄹㅇ그리',
#  '대화',
#  '순간',
#  '아웃',
#  'ㅎㅇ',
#  '연속',
#  '다섯번',
#  '엔프제',
#  '사람',
#  '우리나라',
#  '진심',
#  '엔프제',
#  '많진',
#  '친구',
#  '자기',
#  '대',
#  '2',
#  '3일',
#  '2',
#  '8일',
#  '분명',
#  'intp였는데',
#  '어제',
#  'enfj나왔음',
#  'ㅎㅎ',
#  '애',
#  '재롱떨며',
#  '부모노릇중',
#  '성격',
#  '개조',
#  '디씨',
#  '2n년차',
#  'ㅇㅇ<U+00A0><U+00A0>나이먹으',
#  '유순',
#  '찐엔프제',
#  '인증',
#  '다들',
#  '이상형',
#  '되',
#  '궁금',
#  '엔프제들',
#  '어딨어ㅠ',
#  '엔프제들',
#  '보러왔는데',
#  '엔프제',
#  '없내요어디',
#  '다들',
#  '한국',
#  '엠비티아',
#  '1프로',
#  '현실인가ㅜ',
#  '엔프제',
#  '되',
#  '잇팁',
#  '오늘',
#  '검사',
#  '엔프제',
#  '갤',
#  '있네욬ㅋㅋㅋㅋ',
#  'ㅋ',
#  '글',
#  '없나보',
#  '안녕하세용',
#  '10년',
#  '찐엔프제',
#  '인증',
#  '완료',
#  '검사결괗ㅎ',
#  '근데',
#  '뭐',
#  '것',
#  '뭔',
#  '잡논리',
#  '심리검사',
#  '성격유형같은거',
#  '뭐',
#  '추측',
#  '분석',
#  '개지랄',
#  '(1대1면담',
#  '치료목적',
#  '외',
#  '그런거',
#  '것',
#  '호르몬',
#  '역추적하는',
#  '쉽게말해',
#  '몸을보',
#  '성격',
#  '속',
#  '보는거',
#  '어',
#  '관상',
#  '역학',
#  '외모지상주의',
#  '흠',
#  '뭐',
#  '유두',
#  '색깔',
#  '성격보고',
#  '성격보고',
#  '유두색깔',
#  '이런거',
#  '생각',
#  '것',
#  '여성호르몬',
#  '분비량에따라',
#  '유두색검어짐',
#  '비례관계',
#  '엔프제님들',
#  '인프피',
#  '말많',
#  '얼마안',
#  '엔프제랑',
#  '얘기하는데<U+00A0>엔프제',
#  '분',
#  '다정',
#  '말',
#  '이야기',
#  '잘이어나가지긴',
#  '하는데뭔',
#  '인프피',
#  '저',
#  '옴춍',
#  '나에관한',
#  '방출',
#  '이러고있는데싫어요',
#  'ㅠㅠㅠ',
#  '저',
#  '역',
#  '제가한대',
#  '상대방이랑<U+00A0>카톡하',
#  '재미',
#  '귀찮을거같은데',
#  '<U+00A0',
#  '엔팁',
#  'ㄹㅇ엔프제랑',
#  '안싸워본적이없다',
#  '혐오스러움ㄹㅇ',
#  '친구구해',
#  '♥♥♥♥♥',
#  '♥♥♥♥♥',
#  '♥',
#  '부산살',
#  '26입니다카톡디',
#  '엔프제남자만나',
#  '성격좋은듯',
#  '외향감정',
#  '8기능중',
#  '이해할수없음타인',
#  '감정',
#  '고려한다는게',
#  '가능',
#  '타인본인',
#  '그게됨사람',
#  '사람',
#  '이상',
#  '자기',
#  '기분',
#  '못느끼는',
#  '당연',
#  '상대방',
#  '표정을지을때,',
#  '자기',
#  '그런표정',
#  '어떤기분일때',
#  '떠올려서상대감정',
#  '수',
#  '생각',
#  '이',
#  '내향감정이라던데그냥',
#  '당연한거',
#  '상대',
#  '자신',
#  '이런게',
#  '진짜',
#  '엔팁',
#  '안녕',
#  '엔팁입니다<U+00A0><U+00A0>주위',
#  '엔프제',
#  '것',
#  '같아서',
#  '궁금해서',
#  '들어와봤어',
#  '근데',
#  '글',
#  '얼마없네여그러',
#  '질문받을게여그리',
#  '저',
#  '물어볼거',
#  '있어여엔팁',
#  '어케생각하',
#  '나는야',
#  '여자',
#  '맨날',
#  '습관',
#  '하는말사이좋게',
#  '지내장~~~',
#  'ㅋㅋㅋㅋㅋ',
#  'ㅋ',
#  '엔프제',
#  '되고십당',
#  '근데',
#  '인프피',
#  'ㅜㅜ',
#  '남잔데',
#  '특징',
#  '고칠점,',
#  '강점',
#  '같은거',
#  '고맙겠어용',
#  '엔프제',
#  '인간',
#  '리트리버같다는말',
#  '생각',
#  '나',
#  '싫어병신같아',
#  '애초',
#  '기대',
#  '안',
#  '사랑',
#  '주지만변해가',
#  '상대방',
#  '모습보',
#  '만큼',
#  '슬퍼그래',
#  '관계',
#  '회의적',
#  '생각',
#  '그냥다른',
#  '엔프제들',
#  '인프피갤',
#  '엔프제님들',
#  '인싸',
#  '태생',
#  '아싸였지만ENFJ',
#  '인싸라길래부럽',
#  '진짜',
#  '밑',
#  '글',
#  '공감',
#  '엔프제남이야난',
#  '사람',
#  '사람',
#  '것',
#  '좋고얘기하',
#  '것',
#  '고민',
#  '것',
#  '좋은데요즘',
#  '관계',
#  '지속',
#  '지속',
#  '공허감',
#  '변하는<U+00A0>부분',
#  '날',
#  '것',
#  '같아자존심',
#  '편',
#  '나',
#  '상대방',
#  '것',
#  '모르겠지만그냥',
#  '사랑',
#  '사랑',
#  '데',
#  '마음',
#  '되',
#  '간',
#  '리트리버라',
#  '말',
#  '진짜',
#  '맞긴',
#  '맞나보다남',
#  '사랑',
#  '것',
#  '좋은데되',
#  '주인',
#  '사람',
#  '확실',
#  '사랑',
#  '싶어누',
#  '때마다<U+00A0>유기견',
#  '것',
#  '기분',
#  '느껴진다그냥',
#  '적어봤어어디',
#  '말',
#  '데',
#  '중고딩',
#  'enfj였는데',
#  '지금',
#  'v=d-UMBguNiv0',
#  '엔프제들',
#  '사람',
#  'ㅅㅂ인프제보다',
#  '엔프제',
#  '100배',
#  '후시발',
#  '인프제',
#  '병신',
#  '후',
#  '갤러리',
#  '엔프제',
#  '인간관계',
#  '회피성',
#  '평소',
#  '활발하다가우울하',
#  '잠수타는데어느',
#  '장단',
#  '모르겠음글고',
#  '고민',
#  '들어주면서막상',
#  '자기',
#  '고민',
#  '안말해줌그냥',
#  '대응',
#  '넘모',
#  '어렵다',
#  '회사',
#  '내향',
#  '페르소',
#  '엔프제',
#  '나',
#  '회사',
#  '내향으로<U+00A0>생활하는데',
#  '답답해서',
#  '죽을거',
#  '예비',
#  '엔프제',
#  '입갤',
#  '쪼금',
#  '나',
#  '엔프제남',
#  '엔프제남',
#  '희귀함',
#  '남',
#  '엔프제남',
#  '희귀',
#  '다양',
#  '호기심많고',
#  '친구',
#  '많은편이긴해요좀',
#  '덕후소리',
#  '듣기도합니다',
#  'ㅋㅋ',
#  '갤러리',
#  '안녕하세요',
#  '엔프제랑',
#  '친구하',
#  '잇프피',
#  '나',
#  '궁합',
#  '좋대',
#  '얘들',
#  '반가웡',
#  '엔프제',
#  '흥미',
#  '너',
#  '관찰할거',
#  '인프피',
#  'ㅎ',
#  '엔프제',
#  '연인',
#  '그닥',
#  '나',
#  '엔프제',
#  '사람',
#  '거',
#  '좋아하니데이트할때',
#  '진짜',
#  '챙겨주지만막',
#  '사람들',
#  '약속',
#  '인간관계',
#  '문제',
#  '됨다른',
#  '사람들',
#  '재밌어서',
#  '그동안',
#  '연락',
#  '잘안하',
#  '됨그리',
#  '데이트',
#  '모임약속',
#  '갈등함여친',
#  '소중',
#  '주변사람들',
#  '소중하기에그',
#  '차이뮤ㅠ',
#  '사랑',
#  '뭐',
#  '궁금해',
#  '저',
#  '이상향',
#  '저',
#  '엔프제같',
#  '성격',
#  '가지',
#  '자연',
#  '엔프제들',
#  '중',
#  '자연',
#  '과장',
#  '연기',
#  '말',
#  '행동',
#  '사람',
#  '거부감',
#  '엔프제',
#  '나',
#  '생각',
#  '엔프제한테',
#  '중요',
#  '것',
#  '중',
#  '하나',
#  '자연',
#  '엔프제',
#  '디시',
#  '81',
#  '이거',
#  '나',
#  '10번',
#  '9번',
#  '여잔데(esfj',
#  '한번',
#  '설명',
#  '이거',
#  '나',
#  '것',
#  '많더라고항상',
#  '외향성',
#  '지표',
#  '80퍼',
#  '정도',
#  '자존감',
#  '함개인적',
#  '유형들',
#  '달라지던데(ex.',
#  '엔프피인프피)나만',
#  '엔프제인프제',
#  '성격',
#  '둘',
#  '엔프제들',
#  '사람들',
#  '궁금해아님<U+00A0>다른',
#  '유형들',
#  '외내향성만',
#  '뿐',
#  '본인들',
#  '비슷',
#  '것',
#  '근데',
#  '랑',
#  '제곧내',
#  '영화신과함께',
#  '이덕춘',
#  '엔프제같',
#  '조사중',
#  '의견듣고싶어',
#  '엔프제',
#  '뒷끝',
#  '선물',
#  '정상',
#  '인프피',
#  '주변',
#  '엔프제',
#  '사람들',
#  '엔프제',
#  '조아요',
#  'enfj-a나옴',
#  '근데',
#  '사람',
#  'ㅋㅋ',
#  '기분좋긴',
#  '짝남',
#  '엔프제임데',
#  '인프피',
#  '념글보니까',
#  '엔프제',
#  '하는말',
#  '받아주라하',
#  '출근',
#  '싫다아아아',
#  '출근',
#  '텐션',
#  '다죽는다아아',
#  '기분',
#  '나',
#  '인프피',
#  '궁합표',
#  '엔프제',
#  '엔트제하',
#  '젤',
#  '맞는대서너네',
#  '인프피',
#  '점',
#  '지',
#  '궁금함',
#  '정보',
#  '갤러리별',
#  '단어',
#  '키워드',
#  '분석',
#  '결과',
#  '잇팁',
#  '갤',
#  '궁합',
#  '괜찮다길래',
#  '염탐',
#  'ㅎㅇ',
#  '떴다ㅏㅇ',
#  '근데',
#  '사람이',
#  '판',
#  '갤러리',
#  '못들어가겠어,,,',
#  '만만해',
#  '나',
#  '인티제',
#  '이상형',
#  '엔프제',
#  '엔프제랑',
#  '사귀',
#  'ㅠㅠㅠㅠㅠ',
#  'ㅠㅠㅠㅠㅠ',
#  'ㅠㅠㅠㅠㅠ',
#  'ㅠ',
#  '개나소',
#  '엔프제길래',
#  '나',
#  '엔프제인거',
#  '부정',
#  '나',
#  '몇',
#  '번해',
#  '엔프제',
#  '그넫',
#  '내',
#  '주변애',
#  '엔프제',
#  '개많아',
#  '뭐',
#  '인간들',
#  '[설문조사]카톡',
#  '메시지',
#  '내용',
#  '무엇',
#  '아침',
#  '눈',
#  '핸드폰',
#  '알림창',
#  '누구',
#  '내용',
#  '싶으싶니까',
#  '얘두라',
#  '나',
#  '나왔따',
#  '엌',
#  '신기행',
#  '오옹',
#  '신기해',
#  '나',
#  '친구들',
#  '생일',
#  '뭐',
#  '이러고<U+00A0>선물',
#  '전형적',
#  '엔프제였넹',
#  '<U+00A0',
#  '엔프제',
#  '아낌없이주는나무라든가남',
#  '이타적이란',
#  '말',
#  '싫어지더라내삶좀',
#  '데',
#  '다른사람',
#  '눈',
#  '건강',
#  '엔프제',
#  '되어버렸나봄',
#  '엔프제',
#  '호감',
#  '법',
#  '사람',
#  '엔프제임호감',
#  '법',
#  'ㄱㄱㄱplz',
#  '오늘',
#  '친구',
#  '검사',
#  '이거나옴',
#  '근데',
#  '머저리우량아집합소',
#  'INTP갤',
#  '다르누',
#  '여기',
#  '호구갤',
#  '엔티제에',
#  '이별',
#  '엔프제',
#  '지',
#  '엔티제',
#  '그놈처음',
#  '구애',
#  '때',
#  '세상',
#  '근심',
#  '시름',
#  '듯이자기같',
#  '이기적',
#  '놈',
#  '너',
#  '사랑',
#  '거라고<U+00A0>아주',
#  '들이대더닣ㅎ',
#  '나중',
#  '왜케',
#  '눈치',
#  '너',
#  '니',
#  '인생',
#  '생각',
#  '안하',
#  '나',
#  '미래',
#  '생각하느냐지랄',
#  '허구',
#  '통봌너무너무',
#  '싶었는데걔',
#  '자기한텐',
#  '일',
#  '중요',
#  '것',
#  '같구',
#  '마음',
#  '목적',
#  '의미',
#  '없대서그',
#  '말',
#  '걍',
#  '거',
#  '포기했어목적',
#  '나',
#  '목적이었나볔ㅋ',
#  '생각',
#  '때',
#  '데이트',
#  '일주일',
#  '번',
#  '허용',
#  '웃겨근데',
#  '여자',
#  '딴생각',
#  '놈',
#  '아니야그냥',
#  '존나',
#  '워커홀릭',
#  '일',
#  '미래',
#  '돈',
#  '모르는듯찾아보',
#  '엔티제랑',
#  '사람',
#  '정도',
#  '사교적이라는데글쎄',
#  '나',
#  '누구',
#  '사람',
#  '안정적',
#  '연애',
#  '수',
#  '싶네자',
#  '바운더리',
#  '독립적',
#  '사람',
#  '엔티제',
#  '연애',
#  '수',
#  '싶다가도아',
#  '것',
#  '중요한<U+00A0>사람',
#  '연애',
#  '하나',
#  '하고물론',
#  '사랑',
#  '종류',
#  '여럿이',
#  '호구라성그래',
#  '엔티제',
#  '그놈',
#  '보고싶구나그',
#  '리더십',
#  '확고',
#  '모습',
#  '지',
#  '확실',
#  '말투',
#  '너',
#  '그때',
#  '내',
#  '자존감',
#  '하늘',
#  '찔렀는지엔프제들',
#  '칭찬',
#  '광대<U+00A0>승천하잖니존나',
#  '워커홀릭',
#  '거지',
#  '거칭찬',
#  '인색',
#  '거단칼',
#  '관계',
#  '거미운털',
#  '할말',
#  '쏴대는<U+00A0>거성급한',
#  '거나',
#  '안맞',
#  '것뿐이었는데왜케',
#  '사람',
#  '생각',
#  '나',
#  '싫네나',
#  '사람',
#  '수',
#  '있었을까내',
#  '성격',
#  '장점',
#  '있을까어찌',
#  '상처',
#  '성격',
#  '누구',
#  '안정적',
#  '사랑',
#  '있을까내',
#  '연애',
#  '뭐',
#  '잘못된',
#  '걸까꼬리',
#  '꼬리',
#  '생각들엔프제',
#  '세상',
#  '필요',
#  '빛',
#  '소금',
#  '존재라지만사람들',
#  '빛',
#  '소금',
#  '누구',
#  'ㅋ여전히',
#  '사람',
#  '데',
#  '사람',
#  '미워헤어진지',
#  '이',
#  '연애',
#  '인간',
#  '회의',
#  '힘드네진짜',
#  '밉고아푸',
#  '엔프제',
#  '데',
#  '어케하노',
#  '이쁘면되노',
#  '세상',
#  '인재들',
#  '직관갖춘',
#  '라',
#  '현실',
#  '오아시스',
#  'ㅇㅇ',
#  '이딴',
#  '갤',
#  '있놐ㅋㅋㅋ',
#  '떳냐',
#  '엔티제',
#  '일',
#  '좋아하는거',
#  '효율충인거',
#  '맞는데100마디',
#  '말',
#  '포옹',
#  '생각',
#  '그런거니이해해줘',
#  '몸',
#  '마음',
#  '하잖아그러',
#  '옆',
#  '됨',
#  'ㅎ',
#  '엔프제',
#  'ㅎㅎ예전부터',
#  '검사',
#  '엔프제',
#  '데',
#  '주변',
#  '엔프제',
#  '아무',
#  'Fe라는게',
#  '세상',
#  '존재',
#  '리',
#  'ㅇㅈ',
#  'ㅇㅇㅈ',
#  '인프제랑',
#  '엔프제',
#  '차이',
#  '뭐',
#  '것',
#  '같애',
#  '나',
#  '인프제',
#  '인간관계',
#  '강박',
#  '엔프제',
#  '나',
#  '진짜',
#  '편',
#  '나',
#  '환경때문',
#  '성향때문',
#  '원인',
#  '해결될건',
#  'ㅠㅠ',
#  '대한민국',
#  '2',
#  '테스트',
#  '몇번',
#  '싹다',
#  'enfj나왔어',
#  '한달텀',
#  '두번햇는데',
#  '이거나옴',
#  'ㅠㅠ',
#  '나무위키보다왓음',
#  '사람들',
#  '망ㅎ구',
#  '오',
#  '형',
#  '존',
#  '공감',
#  '혈액형',
#  '성격설',
#  '공감',
#  '자기합리화',
#  '것',
#  '옛날',
#  '때',
#  '이거',
#  'ㅇㅇ',
#  '인프피',
#  '나',
#  '고치고싶은점',
#  '인간형',
#  '테스트',
#  '이거나옴이제부터',
#  '너희',
#  '내',
#  '목표',
#  '진짜',
#  '조금씩',
#  '양보',
#  '조금씩',
#  '배',
#  '될걸아무',
#  '양보안',
#  '아무',
#  '배려안함',
#  '가운데',
#  '피터지',
#  '조율',
#  '것',
#  '같음조금만',
#  '다들',
#  '것',
#  '데',
#  '날',
#  '뭐',
#  '걍',
#  '조금씩',
#  '<U+00A0>',
#  '진짜',
#  '속상',
#  '사람',
#  '나',
#  'ㅅㅂ',
#  '내',
#  '사소한',
#  '특징들',
#  '사람',
#  '인사하는거',
#  '안어려움',
#  '버스',
#  '때',
#  '기사님',
#  '인사함',
#  '음식점',
#  ...]

# %%
from collections import Counter

count = Counter(nouns)
words = dict(count.most_common())
print(words)
# Out:
# {'나': 16626, '것': 11595, '사람': 6982, '생각': 5745, '때': 5074, '말': 4197, '수': 3776, '내': 3502, '진짜': 2930, '친구': 2655, '뭐': 2448, '데': 2308, '근데': 2301, '일': 2152, '너': 1969, '성격': 1861, '애': 1845, '글': 1668, '존': 1658, '거': 1616, '유형': 1615, '듯': 1548, '얘': 1524, '사람들': 1519, '이': 1441, '자기': 1399, '적': 1386, '지': 1259, 'ㅋㅋ': 1174, '그': 1163, '남': 1057, '중': 1046, '마음': 1044, 'ㅋㅋㅋㅋㅋ': 1036, '뭔가': 1033, '엔프제': 1021, '편': 1019, '연락': 997, '감정': 969, '이거': 950, '본인': 930, '누구': 921, '친구들': 904, '관심': 898, '저': 895, '자신': 871, '여자': 852, '이해': 842, '이유': 837, '행동': 830, '라': 825, '인프피': 822, '들': 820, '주변': 816, '걍': 816, '연애': 807, '공부': 802, '하나': 801, '때문': 767, '시간': 760, '남자': 750, '속': 744, '기분': 740, '정도': 739, '인프제': 736, '공감': 734, '엔팁': 725, '여기': 703, '우리': 694, '오늘': 692, '검사': 690, '한번': 686, '전': 680, '인팁': 677, '집': 677, '사랑': 674, '다들': 673, '경우': 672, '엔프피': 670, '대화': 664, 'ㄹㅇ': 659, '특징': 647, '잇프제': 638, '상황': 631, '이상': 627, '성향': 627, '줄': 626, '인생': 614, '상대': 610, '걔': 608, 'ㅋㅋㅋ': 606, '개': 604, '이야기': 602, '엔티제': 586, '문제': 574, '관계': 568, '잇프피': 566, 'ㅇㅇ': 563, '고민': 562, '상대방': 552, '안': 552, '상처': 540, '궁금': 531, '계획': 529, '비슷': 526, '세상': 523, '스트레스': 514, '맨날': 509, '노력': 502, '소리': 501, '갤러리': 497, '얘기': 492, '엄마': 483, '앞': 479, '필요': 476, '지금': 474, '자체': 472, '리': 463, '인간': 458, '인티제': 457, '한': 436, '엣팁': 435, '행복': 434, '눈치': 428, '그것': 428, '결과': 424, 'ㅋ': 423, '테스트': 421, '분위기': 419, '번': 414, '모습': 412, '밖': 407, '부분': 406, '시작': 401, '평소': 397, '이런거': 392, '우울': 386, '표현': 384, '인간관계': 381, '1': 378, '좆': 377, '등': 375, '욕': 371, 'ㅈㄴ': 367, '학교': 367, '카톡': 367, '척': 366, 'ㅋㅋㅋㅋ': 364, '눈': 360, '하루': 360, '차': 354, '현실': 350, '그걸': 347, '사이': 345, '미안': 342, '놈': 341, '책': 341, '삶': 338, '그거': 334, '질문': 332, '화': 330, '타인': 330, '잇티제': 329, '대부분': 328, '니': 323, 'ㅠㅠ': 323, '머리': 318, '뒤': 317, '이성': 316, '자': 315, '둘': 314, '너희': 314, '니들': 314, '처음': 313, '점': 312, '사회': 310, '의미': 309, '시발': 309, '댓글': 309, '갤': 308, '노래': 308, '의견': 308, '곳': 302, '기준': 300, '나중': 295, '완전': 295, '뿐': 294, '1.': 294, '식': 290, '느낌': 288, '끝': 287, '어디': 286, '대': 286, '중요': 286, '이것': 285, '법': 284, '능력': 277, '답': 276, '너넨': 275, '인정': 273, '그런거': 270, '설명': 269, '반응': 268, '잇팁': 267, '아무': 267, '만': 267, '가족': 267, '진심': 266, '그때': 266, '병신': 265, '기억': 264, '경험': 263, '돈': 262, '호감': 261, '몇': 259, '나름': 258, '답답': 257, '걱정': 256, '방법': 255, '도움': 255, '인터넷': 255, '게임': 254, '예전': 253, '거기': 253, '잘못': 250, '아빠': 250, '위': 248, '전화': 248, '2': 247, '자존감': 247, '영화': 247, '후': 245, '차이': 245, '정리': 245, '신기': 245, '남친': 244, 'ㅠ': 243, '무시': 243, '칭찬': 240, '얼굴': 237, '약속': 235, '사실': 233, 'ㅎㅎ': 230, '누군가': 229, '혼자': 229, '하는거': 228, '쪽': 228, 'ㅅㅂ': 227, '니네': 226, '안하': 225, '일단': 224, '면': 224, '부모님': 224, '바': 224, '님': 223, '어느정도': 222, '특': 221, '논리적': 219, '것들': 219, '두': 217, '새끼': 217, '고백': 217, '반대': 216, '분': 215, '회사': 214, '존재': 214, '재미': 213, '<U+00A0': 213, '내용': 212, '상상': 211, '순간': 210, '감정적': 210, '겉': 209, '위로': 208, '해결': 207, '상태': 206, '젤': 205, '짓': 203, '가능': 201, '선': 201, '이상형': 200, '한명': 200, '거리': 198, '씨발': 198, '입장': 197, '선택': 197, '신경': 195, '타입': 194, '되': 193, '이상한': 193, '보': 191, '이성적': 191, '논리': 191, '너희들': 190, '이걸': 190, '3': 190, '직업': 189, '별': 188, '다음': 187, '뭔': 186, '거절': 186, '말투': 185, '목표': 185, '새끼들': 185, '이후': 184, '피곤': 184, '추천': 184, '술': 183, '스스로': 183, '판단': 182, '코': 182, '만큼': 181, '관련': 181, '입': 181, '애초': 180, '반': 180, '부담': 180, '엣프제': 180, '조언': 178, '형': 177, '취미': 177, '운동': 177, '엔프제들': 175, '등등': 175, '인싸': 174, '날': 174, '주제': 174, '단점': 174, '아무것': 173, '어제': 172, '장점': 172, '<U+00A0>': 172, '동생': 172, '옆': 170, '이러': 170, '찐따': 170, '꿈': 169, '은근': 168, '공감능력': 168, '이번': 166, '손절': 165, '현실적': 164, '여친': 163, '함': 163, '멍청': 163, '몸': 162, '옛날': 161, '1년': 161, '어떰': 161, '둘다': 161, '정신': 160, '애인': 160, '손': 160, '밑': 159, '우울증': 159, '한국': 157, '시험': 157, '완벽': 157, '서로': 156, '스타일': 156, '직장': 155, '수준': 155, '긍정적': 154, ' ...

# %%
for word in list(words.keys()):
    if len(word) == 1: # 1인것들 제거
        del words[word]
        continue
        
    if words[word] == 1:
        del words[word]
        
print(words)
# Out:
# {'사람': 6982, '생각': 5745, '진짜': 2930, '친구': 2655, '근데': 2301, '성격': 1861, '유형': 1615, '사람들': 1519, '자기': 1399, 'ㅋㅋ': 1174, '마음': 1044, 'ㅋㅋㅋㅋㅋ': 1036, '뭔가': 1033, '엔프제': 1021, '연락': 997, '감정': 969, '이거': 950, '본인': 930, '누구': 921, '친구들': 904, '관심': 898, '자신': 871, '여자': 852, '이해': 842, '이유': 837, '행동': 830, '인프피': 822, '주변': 816, '연애': 807, '공부': 802, '하나': 801, '때문': 767, '시간': 760, '남자': 750, '기분': 740, '정도': 739, '인프제': 736, '공감': 734, '엔팁': 725, '여기': 703, '우리': 694, '오늘': 692, '검사': 690, '한번': 686, '인팁': 677, '사랑': 674, '다들': 673, '경우': 672, '엔프피': 670, '대화': 664, 'ㄹㅇ': 659, '특징': 647, '잇프제': 638, '상황': 631, '이상': 627, '성향': 627, '인생': 614, '상대': 610, 'ㅋㅋㅋ': 606, '이야기': 602, '엔티제': 586, '문제': 574, '관계': 568, '잇프피': 566, 'ㅇㅇ': 563, '고민': 562, '상대방': 552, '상처': 540, '궁금': 531, '계획': 529, '비슷': 526, '세상': 523, '스트레스': 514, '맨날': 509, '노력': 502, '소리': 501, '갤러리': 497, '얘기': 492, '엄마': 483, '필요': 476, '지금': 474, '자체': 472, '인간': 458, '인티제': 457, '엣팁': 435, '행복': 434, '눈치': 428, '그것': 428, '결과': 424, '테스트': 421, '분위기': 419, '모습': 412, '부분': 406, '시작': 401, '평소': 397, '이런거': 392, '우울': 386, '표현': 384, '인간관계': 381, 'ㅈㄴ': 367, '학교': 367, '카톡': 367, 'ㅋㅋㅋㅋ': 364, '하루': 360, '현실': 350, '그걸': 347, '사이': 345, '미안': 342, '그거': 334, '질문': 332, '타인': 330, '잇티제': 329, '대부분': 328, 'ㅠㅠ': 323, '머리': 318, '이성': 316, '너희': 314, '니들': 314, '처음': 313, '사회': 310, '의미': 309, '시발': 309, '댓글': 309, '노래': 308, '의견': 308, '기준': 300, '나중': 295, '완전': 295, '1.': 294, '느낌': 288, '어디': 286, '중요': 286, '이것': 285, '능력': 277, '너넨': 275, '인정': 273, '그런거': 270, '설명': 269, '반응': 268, '잇팁': 267, '아무': 267, '가족': 267, '진심': 266, '그때': 266, '병신': 265, '기억': 264, '경험': 263, '호감': 261, '나름': 258, '답답': 257, '걱정': 256, '방법': 255, '도움': 255, '인터넷': 255, '게임': 254, '예전': 253, '거기': 253, '잘못': 250, '아빠': 250, '전화': 248, '자존감': 247, '영화': 247, '차이': 245, '정리': 245, '신기': 245, '남친': 244, '무시': 243, '칭찬': 240, '얼굴': 237, '약속': 235, '사실': 233, 'ㅎㅎ': 230, '누군가': 229, '혼자': 229, '하는거': 228, 'ㅅㅂ': 227, '니네': 226, '안하': 225, '일단': 224, '부모님': 224, '어느정도': 222, '논리적': 219, '것들': 219, '새끼': 217, '고백': 217, '반대': 216, '회사': 214, '존재': 214, '재미': 213, '<U+00A0': 213, '내용': 212, '상상': 211, '순간': 210, '감정적': 210, '위로': 208, '해결': 207, '상태': 206, '가능': 201, '이상형': 200, '한명': 200, '거리': 198, '씨발': 198, '입장': 197, '선택': 197, '신경': 195, '타입': 194, '이상한': 193, '이성적': 191, '논리': 191, '너희들': 190, '이걸': 190, '직업': 189, '다음': 187, '거절': 186, '말투': 185, '목표': 185, '새끼들': 185, '이후': 184, '피곤': 184, '추천': 184, '스스로': 183, '판단': 182, '만큼': 181, '관련': 181, '애초': 180, '부담': 180, '엣프제': 180, '조언': 178, '취미': 177, '운동': 177, '엔프제들': 175, '등등': 175, '인싸': 174, '주제': 174, '단점': 174, '아무것': 173, '어제': 172, '장점': 172, '<U+00A0>': 172, '동생': 172, '이러': 170, '찐따': 170, '은근': 168, '공감능력': 168, '이번': 166, '손절': 165, '현실적': 164, '여친': 163, '멍청': 163, '옛날': 161, '1년': 161, '어떰': 161, '둘다': 161, '정신': 160, '애인': 160, '우울증': 159, '한국': 157, '시험': 157, '완벽': 157, '서로': 156, '스타일': 156, '직장': 155, '수준': 155, '긍정적': 154, '친구들이': 154, '대학': 154, '최근': 154, '짝사랑': 154, '같은거': 153, '유형들': 153, '무엇': 153, '평생': 153, '진지': 153, '대답': 153, '마지막': 153, '답장': 151, '사회성': 150, '사회생활': 148, '여자들': 148, '궁합': 147, '자리': 147, '이기적': 146, '결혼': 146, '눈물': 146, '지능': 146, '에너지': 145, '미래': 145, '주장': 145, '특성': 144, '후회': 144, '군대': 144, '헤일': 144, '세이탄': 144, '외모': 143, '최고': 143, '부정적': 143, '집중': 143, '장난': 143, '성공': 143, '과정': 142, '과거': 142, '주위': 140, '분석': 140, '있는거': 140, '집착': 140, '요즘': 140, '엣프피': 140, '여자친구': 138, '망상': 138, 'ㅈㄱㄴ': 138, '어케': 137, '상관': 137, '무리': 137, '여자애': 137, '가능성': 137, '유튜브': 136, '준비': 136, '표정': 135, '이미지': 135, '경향': 135, '객관적': 135, '영향': 134, '왤케': 134, '확실': 133, '선물': 133, '얘들': 132, '흥미': 132, '재밌': 132, '분명': 131, '불건강': 130, '남자들': 130, '실수': 130, '단어': 129, '비율': 129, '오랜만': 128, '마인드': 128, '엠비티아': 127, '연인': 127, '친절': 127, '너네들': 127, '오지': 127, '자신감': 126, '당연': 125, '고통': 125, '건강': 124, '뭔지': 124, '분야': 124, '인스타': 123, '생활': 123, '자연': 122, '존나': 122, '심심': 122, '기본적': 122, '할말 ...

# %%
import pickle

with open('MBTI.pickle', 'wb') as f:
    pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)

# %%
len(words)
# Out:
# 22920

# %%
words
# Out:
# {'사람': 6982,
#  '생각': 5745,
#  '진짜': 2930,
#  '친구': 2655,
#  '근데': 2301,
#  '성격': 1861,
#  '유형': 1615,
#  '사람들': 1519,
#  '자기': 1399,
#  'ㅋㅋ': 1174,
#  '마음': 1044,
#  'ㅋㅋㅋㅋㅋ': 1036,
#  '뭔가': 1033,
#  '엔프제': 1021,
#  '연락': 997,
#  '감정': 969,
#  '이거': 950,
#  '본인': 930,
#  '누구': 921,
#  '친구들': 904,
#  '관심': 898,
#  '자신': 871,
#  '여자': 852,
#  '이해': 842,
#  '이유': 837,
#  '행동': 830,
#  '인프피': 822,
#  '주변': 816,
#  '연애': 807,
#  '공부': 802,
#  '하나': 801,
#  '때문': 767,
#  '시간': 760,
#  '남자': 750,
#  '기분': 740,
#  '정도': 739,
#  '인프제': 736,
#  '공감': 734,
#  '엔팁': 725,
#  '여기': 703,
#  '우리': 694,
#  '오늘': 692,
#  '검사': 690,
#  '한번': 686,
#  '인팁': 677,
#  '사랑': 674,
#  '다들': 673,
#  '경우': 672,
#  '엔프피': 670,
#  '대화': 664,
#  'ㄹㅇ': 659,
#  '특징': 647,
#  '잇프제': 638,
#  '상황': 631,
#  '이상': 627,
#  '성향': 627,
#  '인생': 614,
#  '상대': 610,
#  'ㅋㅋㅋ': 606,
#  '이야기': 602,
#  '엔티제': 586,
#  '문제': 574,
#  '관계': 568,
#  '잇프피': 566,
#  'ㅇㅇ': 563,
#  '고민': 562,
#  '상대방': 552,
#  '상처': 540,
#  '궁금': 531,
#  '계획': 529,
#  '비슷': 526,
#  '세상': 523,
#  '스트레스': 514,
#  '맨날': 509,
#  '노력': 502,
#  '소리': 501,
#  '갤러리': 497,
#  '얘기': 492,
#  '엄마': 483,
#  '필요': 476,
#  '지금': 474,
#  '자체': 472,
#  '인간': 458,
#  '인티제': 457,
#  '엣팁': 435,
#  '행복': 434,
#  '눈치': 428,
#  '그것': 428,
#  '결과': 424,
#  '테스트': 421,
#  '분위기': 419,
#  '모습': 412,
#  '부분': 406,
#  '시작': 401,
#  '평소': 397,
#  '이런거': 392,
#  '우울': 386,
#  '표현': 384,
#  '인간관계': 381,
#  'ㅈㄴ': 367,
#  '학교': 367,
#  '카톡': 367,
#  'ㅋㅋㅋㅋ': 364,
#  '하루': 360,
#  '현실': 350,
#  '그걸': 347,
#  '사이': 345,
#  '미안': 342,
#  '그거': 334,
#  '질문': 332,
#  '타인': 330,
#  '잇티제': 329,
#  '대부분': 328,
#  'ㅠㅠ': 323,
#  '머리': 318,
#  '이성': 316,
#  '너희': 314,
#  '니들': 314,
#  '처음': 313,
#  '사회': 310,
#  '의미': 309,
#  '시발': 309,
#  '댓글': 309,
#  '노래': 308,
#  '의견': 308,
#  '기준': 300,
#  '나중': 295,
#  '완전': 295,
#  '1.': 294,
#  '느낌': 288,
#  '어디': 286,
#  '중요': 286,
#  '이것': 285,
#  '능력': 277,
#  '너넨': 275,
#  '인정': 273,
#  '그런거': 270,
#  '설명': 269,
#  '반응': 268,
#  '잇팁': 267,
#  '아무': 267,
#  '가족': 267,
#  '진심': 266,
#  '그때': 266,
#  '병신': 265,
#  '기억': 264,
#  '경험': 263,
#  '호감': 261,
#  '나름': 258,
#  '답답': 257,
#  '걱정': 256,
#  '방법': 255,
#  '도움': 255,
#  '인터넷': 255,
#  '게임': 254,
#  '예전': 253,
#  '거기': 253,
#  '잘못': 250,
#  '아빠': 250,
#  '전화': 248,
#  '자존감': 247,
#  '영화': 247,
#  '차이': 245,
#  '정리': 245,
#  '신기': 245,
#  '남친': 244,
#  '무시': 243,
#  '칭찬': 240,
#  '얼굴': 237,
#  '약속': 235,
#  '사실': 233,
#  'ㅎㅎ': 230,
#  '누군가': 229,
#  '혼자': 229,
#  '하는거': 228,
#  'ㅅㅂ': 227,
#  '니네': 226,
#  '안하': 225,
#  '일단': 224,
#  '부모님': 224,
#  '어느정도': 222,
#  '논리적': 219,
#  '것들': 219,
#  '새끼': 217,
#  '고백': 217,
#  '반대': 216,
#  '회사': 214,
#  '존재': 214,
#  '재미': 213,
#  '<U+00A0': 213,
#  '내용': 212,
#  '상상': 211,
#  '순간': 210,
#  '감정적': 210,
#  '위로': 208,
#  '해결': 207,
#  '상태': 206,
#  '가능': 201,
#  '이상형': 200,
#  '한명': 200,
#  '거리': 198,
#  '씨발': 198,
#  '입장': 197,
#  '선택': 197,
#  '신경': 195,
#  '타입': 194,
#  '이상한': 193,
#  '이성적': 191,
#  '논리': 191,
#  '너희들': 190,
#  '이걸': 190,
#  '직업': 189,
#  '다음': 187,
#  '거절': 186,
#  '말투': 185,
#  '목표': 185,
#  '새끼들': 185,
#  '이후': 184,
#  '피곤': 184,
#  '추천': 184,
#  '스스로': 183,
#  '판단': 182,
#  '만큼': 181,
#  '관련': 181,
#  '애초': 180,
#  '부담': 180,
#  '엣프제': 180,
#  '조언': 178,
#  '취미': 177,
#  '운동': 177,
#  '엔프제들': 175,
#  '등등': 175,
#  '인싸': 174,
#  '주제': 174,
#  '단점': 174,
#  '아무것': 173,
#  '어제': 172,
#  '장점': 172,
#  '<U+00A0>': 172,
#  '동생': 172,
#  '이러': 170,
#  '찐따': 170,
#  '은근': 168,
#  '공감능력': 168,
#  '이번': 166,
#  '손절': 165,
#  '현실적': 164,
#  '여친': 163,
#  '멍청': 163,
#  '옛날': 161,
#  '1년': 161,
#  '어떰': 161,
#  '둘다': 161,
#  '정신': 160,
#  '애인': 160,
#  '우울증': 159,
#  '한국': 157,
#  '시험': 157,
#  '완벽': 157,
#  '서로': 156,
#  '스타일': 156,
#  '직장': 155,
#  '수준': 155,
#  '긍정적': 154,
#  '친구들이': 154,
#  '대학': 154,
#  '최근': 154,
#  '짝사랑': 154,
#  '같은거': 153,
#  '유형들': 153,
#  '무엇': 153,
#  '평생': 153,
#  '진지': 153,
#  '대답': 153,
#  '마지막': 153,
#  '답장': 151,
#  '사회성': 150,
#  '사회생활': 148,
#  '여자들': 148,
#  '궁합': 147,
#  '자리': 147,
#  '이기적': 146,
#  '결혼': 146,
#  '눈물': 146,
#  '지능': 146,
#  '에너지': 145,
#  '미래': 145,
#  '주장': 145,
#  '특성': 144,
#  '후회': 144,
#  '군대': 144,
#  '헤일': 144,
#  '세이탄': 144,
#  '외모': 143,
#  '최고': 143,
#  '부정적': 143,
#  '집중': 143,
#  '장난': 143,
#  '성공': 143,
#  '과정': 142,
#  '과거': 142,
#  '주위': 140,
#  '분석': 140,
#  '있는거': 140,
#  '집착': 140,
#  '요즘': 140,
#  '엣프피': 140,
#  '여자친구': 138,
#  '망상': 138,
#  'ㅈㄱㄴ': 138,
#  '어케': 137,
#  '상관': 137,
#  '무리': 137,
#  '여자애': 137,
#  '가능성': 137,
#  '유튜브': 136,
#  '준비': 136,
#  '표정': 135,
#  '이미지': 135,
#  '경향': 135,
#  '객관적': 135,
#  '영향': 134,
#  '왤케': 134,
#  '확실': 133,
#  '선물': 133,
#  '얘들': 132,
#  '흥미': 132,
#  '재밌': 132,
#  '분명': 131,
#  '불건강': 130,
#  '남자들': 130,
#  '실수': 130,
#  '단어': 129,
#  '비율': 129,
#  '오랜만': 128,
#  '마인드': 128,
#  '엠비티아': 127,
#  '연인': 127,
#  '친절': 127,
#  '너네들': 127,
#  '오지': 127,
#  '자신감': 126,
#  '당연': 125,
#  '고통': 125,
#  '건강': 124,
#  '뭔지': 124,
#  '분야': 124,
#  '인스타': 123,
#  '생활': 123,
#  '자연': 122,
#  '존나': 122,
#  '심심': 122,
#  '기본적': 122,
#  '할말': 121,
#  '결론': 121,
#  '외향적': 120,
#  '솔직': 120,
#  '2.': 120,
#  '멘탈': 119,
#  '생각해': 119,
#  '모두': 119,
#  '안보': 119,
#  '자유': 119,
#  '발전': 119,
#  '아침': 118,
#  '반복': 118,
#  '이젠': 118,
#  '안녕': 117,
#  '가치': 117,
#  '지적': 117,
#  '불안': 114,
#  '몇번': 113,
#  '사과': 113,
#  '가치관': 113,
#  '만족': 113,
#  '새벽': 113,
#  '드라마': 112,
#  '예의': 112,
#  '태도': 112,
#  '엣티제': 112,
#  '오해': 111,
#  '무언가': 111,
#  '아싸': 110,
#  '머릿속': 110,
#  '방식': 110,
#  '상사': 110,
#  '하루종일': 109,
#  '추구': 109,
#  '사회적': 109,
#  'ㅎㅇ': 108,
#  '중간': 108,
#  '특별': 108,
#  '얼마': 107,
#  '일상': 107,
#  '환경': 107,
#  '한마디': 106,
#  '매력': 106,
#  '그사람': 105,
#  '이것저것': 105,
#  '의외': 105,
#  '잇프제들': 105,
#  '정의': 105,
#  '아이': 105,
#  '성적': 105,
#  '엔프피들': 105,
#  '의지': 104,
#  '짜증': 104,
#  '확신': 104,
#  '포기': 104,
#  '부탁': 103,
#  '토론': 103,
#  '확인': 103,
#  '참고': 103,
#  '암튼': 103,
#  '취향': 103,
#  '불편': 102,
#  'ㅜㅜ': 102,
#  '정보': 102,
#  '감사': 102,
#  '세계': 102,
#  '호구': 101,
#  '쓰레기': 101,
#  '팩트': 101,
#  '이런식': 101,
#  '순수': 101,
#  '혐오': 101,
#  '디씨': 99,
#  '가지': 99,
#  '이름': 99,
#  '지랄': 99,
#  '거짓말': 98,
#  '단순': 98,
#  '나머지': 98,
#  '기능': 98,
#  '누나': 97,
#  '사용': 96,
#  '몇년': 96,
#  '절대': 96,
#  'ㅡㅡㅡㅡㅡ': 96,
#  '어색': 95,
#  '뭘까': 95,
#  '평가': 95,
#  '동안': 95,
#  '남자친구': 95,
#  '근거': 95,
#  '생일': 94,
#  '반반': 94,
#  '시선': 94,
#  '음악': 94,
#  '3.': 94,
#  '영상': 94,
#  '파악': 94,
#  '내향': 93,
#  '소중': 93,
#  '목적': 93,
#  '자존심': 93,
#  '상담': 93,
#  '애매': 93,
#  '인사': 93,
#  '조용': 93,
#  '부모': 93,
#  '주말': 93,
#  '계획적': 93,
#  '거지': 92,
#  '감성': 92,
#  '종교': 92,
#  '조심': 91,
#  '결정': 91,
#  '언제': 91,
#  '극단적': 91,
#  '자랑': 90,
#  '적극적': 90,
#  '학창시절': 90,
#  '선호': 90,
#  '속마음': 90,
#  '적응': 90,
#  '당신': 89,
#  '두번': 89,
#  '전부': 89,
#  '성실': 89,
#  '디시': 88,
#  '집단': 88,
#  '반박': 88,
#  '캐릭터': 88,
#  '한번씩': 87,
#  '내향적': 87,
#  '텐션': 86,
#  'ㅠㅠㅠㅠㅠ': 86,
#  '고등학교': 86,
#  '사랑해': 86,
#  '지들': 86,
#  '과제': 86,
#  '엔팁들': 86,
#  '다른사람': 85,
#  '안맞': 85,
#  '이상적': 85,
#  '특유': 85,
#  '<U+00A0><U+00A0>': 85,
#  '정신적': 85,
#  '인간들': 84,
#  '검색': 84,
#  '한달': 84,
#  '작년': 84,
#  '인성': 84,
#  '선생님': 84,
#  '리액션': 83,
#  '안좋': 83,
#  '활동': 83,
#  '제외': 83,
#  '구분': 83,
#  '꼰대': 83,
#  '실망': 82,
#  '아래': 82,
#  '이용': 82,
#  '엣팁들': 82,
#  '궁금해': 81,
#  '조금씩': 81,
#  '100': 81,
#  '4.': 81,
#  '이때': 81,
#  '졸업': 81,
#  '이럼': 81,
#  '활발': 81,
#  '열등감': 81,
#  '일주일': 80,
#  '외로움': 80,
#  '2년': 80,
#  '책임감': 80,
#  '착각': 80,
#  '극혐': 80,
#  '목소리': 80,
#  '관리': 80,
#  '조금': 79,
#  '감성적': 79,
#  '나이': 79,
#  '외향': 79,
#  '정반대': 79,
#  '10': 79,
#  '기질': 79,
#  '확률': 79,
#  '편안': 78,
#  '기회': 78,
#  '가족들': 78,
#  '통제': 78,
#  '성격유형': 77,
#  '만화': 77,
#  '가슴': 77,
#  '차이점': 77,
#  '생각함': 77,
#  '페미': 76,
#  '내면': 76,
#  '평범': 76,
#  '변화': 76,
#  '술자리': 76,
#  '학원': 76,
#  '신념': 76,
#  '여행': 76,
#  '있긴': 76,
#  '주관': 76,
#  '고집': 76,
#  '습관': 75,
#  '연기': 75,
#  '2번': 75,
#  '예민': 75,
#  '부족': 75,
#  '아버지': 75,
#  '처럼': 75,
#  '서운': 75,
#  '발표': 75,
#  '인프제들': 75,
#  '궁금해서': 74,
#  '물건': 74,
#  '소설': 74,
#  '직설적': 74,
#  '올해': 74,
#  '할거': 74,
#  '안해': 74,
#  '해당': 74,
#  '각자': 74,
#  '3년': 74,
#  '정확': 74,
#  '특이': 74,
#  '절친': 74,
#  '개소리': 74,
#  '이런건': 73,
#  '커뮤니티': 73,
#  '20대': 73,
#  '전공': 73,
#  '엔티제들': 73,
#  '공무원': 73,
#  '정신병': 72,
#  '아닌거': 72,
#  '지식': 72,
#  '개념': 72,
#  '계산': 72,
#  '포함': 72,
#  '10년': 71,
#  '의식': 71,
#  '여러분': 71,
#  '여유': 71,
#  '배려': 71,
#  '사건': 71,
#  '인팁들': 71,
#  '잔소리': 71,
#  '잇프피들': 71,
#  '유행': 70,
#  '몇개': 70,
#  '관찰': 70,
#  '어떤지': 70,
#  '심리': 70,
#  '효율적': 70,
#  '카페': 70,
#  '정상': 69,
#  '마음속': 69,
#  '결국': 69,
#  '사고방식': 69,
#  '에고그램': 69,
#  '방향': 69,
#  '실제': 68,
#  '대학교': 68,
#  '하나씩': 68,
#  '주인공': 68,
#  '마스크': 68,
#  '인기': 68,
#  '관점': 68,
#  '최악': 68,
#  '기본': 68,
#  '부터': 68,
#  '수능': 68,
#  '해결책': 68,
#  '문화': 68,
#  '나무위키': 67,
#  '업무': 67,
#  '실패': 67,
#  '사이트': 67,
#  '극도': 67,
#  '그날': 67,
#  '평화': 67,
#  '존중': 67,
#  '극복': 67,
#  '내일': 67,
#  '부지런': 67,
#  '직관': 67,
#  '영어': 67,
#  '인팁갤': 66,
#  '스타': 66,
#  '없는거': 66,
#  '당황': 66,
#  '해석': 66,
#  '제목': 66,
#  '뒷담': 66,
#  '당시': 66,
#  '특정': 66,
#  '다수': 66,
#  '한남': 66,
#  '다정': 65,
#  '그동안': 65,
#  '부정': 65,
#  '바보': 65,
#  '3번': 65,
#  '본성': 65,
#  '맞는거': 65,
#  '가정': 65,
#  '의도': 65,
#  '글리젠': 65,
#  '1번': 65,
#  '영혼': 64,
#  '16': 64,
#  '즉흥적': 64,
#  '연예': 64,
#  '마찬가지': 64,
#  '존경': 64,
#  '영역': 64,
#  '회피': 64,
#  '원칙': 64,
#  '애니어그램': 63,
#  '사적': 63,
#  '취급': 63,
#  '사업': 63,
#  '인프피들': 63,
#  '규칙': 63,
#  '최선': 63,
#  '성인': 63,
#  '개인': 63,
#  '념글': 63,
#  '아이디어': 63,
#  '아이큐': 63,
#  '좋아하는거': 62,
#  '사진': 62,
#  '심각': 62,
#  '페르소나': 62,
#  '철학': 62,
#  '재능': 62,
#  '현재': 62,
#  '신뢰': 62,
#  '평균': 62,
#  'ㅡㅡ': 61,
#  '지인': 61,
#  '재밌다': 61,
#  '참여': 61,
#  '시절': 61,
#  '강요': 61,
#  '여성': 61,
#  '두개': 61,
#  '그런건': 61,
#  '초반': 61,
#  '완벽주의': 61,
#  '의문': 61,
#  '융통성': 61,
#  '동기': 60,
#  '말하는거': 60,
#  '이득': 60,
#  '납득': 60,
#  '일반적': 60,
#  '이런': 60,
#  '불쌍': 60,
#  '도어슬램': 60,
#  '며칠': 60,
#  '한계': 60,
#  '저번': 60,
#  '우리나라': 59,
#  '기대': 59,
#  '말하기': 59,
#  '일부': 59,
#  '소심': 59,
#  '요구': 59,
#  '한심': 59,
#  '취업': 59,
#  '교육': 59,
#  '자식': 59,
#  '가면': 59,
#  '한테': 59,
#  '엔팁갤': 59,
#  '신기해': 58,
#  '왜케': 58,
#  '다음날': 58,
#  '이정도': 58,
#  '계속': 58,
#  '공유': 58,
#  '동아리': 58,
#  '감정기복': 58,
#  '관심사': 58,
#  '발견': 58,
#  '스토리': 58,
#  '인프피랑': 58,
#  '비교': 58,
#  '요리': 57,
#  '고3': 57,
#  '깔끔': 57,
#  '음식': 57,
#  '오빠': 57,
#  '담배': 57,
#  '자기들': 57,
#  '피해자': 57,
#  '강아지': 57,
#  '동물': 57,
#  '유형별': 57,
#  '일본': 57,
#  'ㅇㅈ': 56,
#  '안쓰': 56,
#  '인연': 56,
#  '공통점': 56,
#  '부류': 56,
#  '공간': 56,
#  '몇몇': 56,
#  '하나하나': 56,
#  '수치': 56,
#  'ㄷㄷ': 56,
#  '대상': 56,
#  '내성적': 56,
#  '효율': 56,
#  '천재': 56,
#  '궁금함': 55,
#  '핸드폰': 55,
#  '가식적': 55,
#  '덕분': 55,
#  '냉정': 55,
#  '많이하': 55,
#  '한두번': 55,
#  '이정': 55,
#  '답변': 55,
#  '되는거': 55,
#  '분노': 55,
#  '차단': 55,
#  '개념글': 55,
#  '도전': 55,
#  '특성상': 55,
#  '잘맞': 55,
#  '주관적': 55,
#  '페르소': 54,
#  '전형적': 54,
#  '그룹': 54,
#  '부족한': 54,
#  '믿음': 54,
#  '고생': 54,
#  '문장': 54,
#  '비판': 54,
#  '편견': 54,
#  '모든걸': 54,
#  '저녁': 54,
#  '농담': 54,
#  '섹스': 54,
#  '문자': 54,
#  '에니어그램': 54,
#  '전자': 54,
#  '욕구': 54,
#  '합리적': 54,
#  '데이트': 53,
#  '구체적': 53,
#  '손절하': 53,
#  '가식': 53,
#  '1시간': 53,
#  '노잼': 53,
#  '왕따': 53,
#  '대인관계': 53,
#  '과학': 53,
#  '잇티제들': 53,
#  '꼬리': 52,
#  '고민상담': 52,
#  '정말': 52,
#  '전여친': 52,
#  '수업': 52,
#  '안가': 52,
#  '역할': 52,
#  '철저': 52,
#  '재밌고': 52,
#  '예술': 52,
#  '따뜻한': 52,
#  '있을까': 52,
#  '학생': 52,
#  '성별': 52,
#  '비난': 52,
#  '빡치': 52,
#  '인티제들': 52,
#  '외향성': 51,
#  '재밌음': 51,
#  '용기': 51,
#  '침대': 51,
#  '자살': 51,
#  '제시': 51,
#  '모순': 51,
#  '집안': 51,
#  '왜냐': 51,
#  '성장': 51,
#  '교수': 51,
#  '나라': 51,
#  '동네': 51,
#  '행위': 51,
#  '다행': 51,
#  '최소한': 51,
#  '언니': 51,
#  '본인들': 50,
#  '하는건': 50,
#  '이전': 50,
#  '설문': 50,
#  '따뜻': 50,
#  '불가능': 50,
#  '보수적': 50,
#  '이론': 50,
#  '사상': 50,
#  '남자애': 50,
#  '애교': 50,
#  '자기애': 50,
#  '성욕': 50,
#  '간섭': 50,
#  '일반': 50,
#  '자기주장': 50,
#  '소수': 50,
#  '잘맞음': 50,
#  '말싸움': 50,
#  '3명': 49,
#  '구경': 49,
#  '어떠': 49,
#  '재수': 49,
#  '차분': 49,
#  '진행': 49,
#  '또라이': 49,
#  '두명': 49,
#  '감각': 49,
#  '애정표현': 49,
#  '성숙': 49,
#  '기간': 49,
#  '시대': 49,
#  '주기능': 49,
#  '증명': 49,
#  'ㅠㅠㅠ': 48,
#  '이딴': 48,
#  '본질': 48,
#  '가사': 48,
#  '선톡': 48,
#  '소개': 48,
#  '자극': 48,
#  '좋은거': 48,
#  '5.': 48,
#  '커뮤': 48,
#  '인붕': 48,
#  '어그': 48,
#  '패턴': 48,
#  '의욕': 48,
#  '링크': 48,
#  '예상': 48,
#  '사고': 48,
#  '3일': 47,
#  '사소한': 47,
#  '여러번': 47,
#  '조용한': 47,
#  '뭐랄까': 47,
#  '억울': 47,
#  '어려움': 47,
#  '도덕적': 47,
#  '몇명': 47,
#  '추측': 46,
#  '인프피갤': 46,
#  '안정적': 46,
#  '같애': 46,
#  '속상': 46,
#  '신경쓰': 46,
#  '사소': 46,
#  '후배': 46,
#  '안정': 46,
#  '컴퓨터': 46,
#  '8기능': 46,
#  '오지랖': 46,
#  '머리속': 46,
#  '소통': 46,
#  '일반화': 46,
#  '시도': 46,
#  '얼마전': 46,
#  '일정': 46,
#  '명확': 46,
#  '가스라이팅': 46,
#  '미련': 46,
#  '언어': 46,
#  'ㅂㅅ': 46,
#  '추억': 45,
#  '청소': 45,
#  '잘못한': 45,
#  '어쩌다': 45,
#  '연습': 45,
#  '설문조사': 45,
#  '복잡': 45,
#  '사는거': 45,
#  '불만': 45,
#  '4번': 45,
#  '2명': 45,
#  '위치': 45,
#  '유일': 45,
#  '1명': 45,
#  '마무리': 45,
#  '귀여움': 45,
#  '이새끼': 45,
#  '뚜렷': 45,
#  '포인트': 45,
#  '다른거': 45,
#  '저거': 45,
#  '어느순간': 45,
#  '어른': 45,
#  '만한': 45,
#  '조합': 45,
#  '이런걸': 45,
#  '<U+200B>': 45,
#  '방구석': 45,
#  '씹프피': 45,
#  '인붕이들': 45,
#  '5년': 44,
#  '다양': 44,
#  '주변사람들': 44,
#  '웃음': 44,
#  '안뇽': 44,
#  '애정': 44,
#  '그땐': 44,
#  '분류': 44,
#  '표출': 44,
#  '아이돌': 44,
#  '조사': 44,
#  '뭔데': 44,
#  '반면': 44,
#  '매력적': 44,
#  '완장': 44,
#  '그들': 44,
#  '동의': 44,
#  '무례': 44,
#  '어딘가': 44,
#  '인프제랑': 43,
#  '친구관계': 43,
#  '다른사람들': 43,
#  '다같': 43,
#  '내성격': 43,
#  '피해': 43,
#  '사회화': 43,
#  '진실': 43,
#  '감동': 43,
#  '응원': 43,
#  '같긴': 43,
#  '가난': 43,
#  '어느날': 43,
#  '날씨': 43,
#  '대단': 43,
#  '온라인': 43,
#  '거리두': 43,
#  ...}

# %%
import pickle
import gzip

# save and compress.
with gzip.open('MBTIzip.pickle', 'wb') as f:
    pickle.dump(words, f)

# %% [markdown]
# ## 성격별 명사 추출 위 코드를 재사용
#
# 위와 같이 성격별 데이터를 합치지 않고 성격별 데이터를 따로 처리 후
#
# 피클파일로 저장

# %%
import os
from glob import glob 

data_name_list = glob("*.csv")
data_name_list 
data_dict = {}

for name in data_name_list :
  path = os.path.join(name)
  data = pd.read_csv(path,encoding='cp949', index_col=0)
  data_dict[str(name[0:4])] = data 

print(f'Succesfully loaded {len(data_dict)} data')
# Out:
# Succesfully loaded 16 data

# %%
data_dict['ESTJ']
# Out:
#      num  ...                                            content
# 1      4  ...                                                 -
# 2      7  ...                             반갑소잉~~<U+00A0>
# 3      9  ...                                           존나 조용하네
# 4     10  ...                                       근데 나도 estj임
# 5     11  ...                                            반갑습니다.
# ..   ...  ...                                                ...
# 486  736  ...                              어렷을때부터 불우한 환경을 살았습니다
# 487  739  ...                             솔직히 처음에는 융통성없고 고지식해보여서
# 488  740  ...                                                제곧내
# 489  742  ...                                        문제는 상대가 나한테
# 490  746  ...  ㅋㅋ estj랑 istj,isfj랑 동일한줄아나? 기억이라니 ㅋㅋ경찰이 니편인것은 ...
#
# [490 rows x 3 columns]

# %%
# labeling 
for label in data_dict.keys():
  data_dict[label]['label'] = label

# %%
data_dict['ESTJ'].head()
# Out:
#    num                   title                          content label
# 1    4                 ESTJ갤러리                               -   ESTJ
# 2    7           아따잉 첫빠여라~~ ㅋㅋ           반갑소잉~~<U+00A0>          ESTJ
# 3    9             여긴 왜 사람이 없냐                         존나 조용하네   ESTJ
# 4   10    estj는 인싸들이어서 글쓸시간도없음                     근데 나도 estj임   ESTJ
# 5   11  MBTI 갤러리에서 떡 돌리러 왔습니다.                          반갑습니다.   ESTJ

# %%
def functionalize_counter(result,label):
  result = result.drop('num', axis=1)
  result = result.reset_index().drop(['index'],axis=1)
  result['title'] = result['title'].str.strip() #공백제거
  result['content'] = result['content'].str.strip() # 공백제거

  result['title'].replace('',np.nan, inplace=True) # 제목없는 경우 nan 대체
  result['content'].replace('', np.nan, inplace=True)

  result.dropna()

  extractor = Hannanum()
  nouns = []

  for i, row, in tqdm(result.iterrows()):
    title, content,label = row

    if title and type(title) is str:
      nouns.extend(extractor.nouns(title))

    if content and type(content) is str:
      nouns.extend(extractor.nouns(content))


  count = Counter(nouns)
  words = dict(count.most_common())

  for word in list(words.keys()):
      if len(word) == 1: # 1인것들 제거
          del words[word]
          continue
          
      if words[word] == 1:
          del words[word]

  # save and compress.
  with gzip.open(label+'_MBTIzip.pickle', 'wb') as f:
      pickle.dump(words, f)

# %%
for label in data_dict.keys():
  data = data_dict[label]
  functionalize_counter(data, label)
# Out:
# 2229it [00:58, 38.01it/s]
# 2041it [00:20, 101.24it/s]
# 1714it [00:26, 63.88it/s]
# 2218it [00:26, 84.92it/s]
# 755it [00:09, 76.33it/s]
# 710it [00:07, 90.87it/s]
# 490it [00:09, 52.89it/s]
# 1815it [00:28, 62.75it/s]
# 2131it [00:51, 41.29it/s]
# 1966it [00:14, 132.68it/s]
# 1478it [00:23, 62.92it/s]
# 2343it [00:30, 76.19it/s]
# 2347it [00:27, 86.44it/s]
# 2257it [00:32, 70.37it/s]
# 1284it [00:09, 129.08it/s]
# 2464it [00:25, 97.46it/s]
